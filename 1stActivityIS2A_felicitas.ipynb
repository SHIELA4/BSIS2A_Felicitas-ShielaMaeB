# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/shmeisce/github_IS2A/main/example.csv')

# %%
df.head()
# Out:
#    age   income  gender  purchased
# 0   32      NaN    male        1.0
# 1   23  12323.0  female        1.0
# 2   23   4423.0     NaN        0.0
# 3   44   1345.0  female        NaN
# 4   43  54523.0     NaN        1.0

# %%
df.tail(1)
# Out:
#    age  income  gender  purchased
# 5   12  2312.0  female        1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        6 non-null      int64
#  1   income     5 non-null      float64
#  2   gender     4 non-null      object
#  3   purchased  5 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 320.0+ bytes

# %%
df.describe()
# Out:
#              age        income  purchased
# count   6.000000      5.000000   5.000000
# mean   29.500000  14985.200000   0.800000
# std    12.565827  22519.713924   0.447214
# min    12.000000   1345.000000   0.000000
# 25%    23.000000   2312.000000   1.000000
# 50%    27.500000   4423.000000   1.000000
# 75%    40.250000  12323.000000   1.000000
# max    44.000000  54523.000000   1.000000

# %%
df.shape
# Out:
# (6, 4)

# %%
df.columns
# Out:
# Index(['age', 'income', 'gender', 'purchased'], dtype='object')

# %%
df = df.drop('gender', axis=1)

# %%
df.head()
# Out:
#    age   income  gender  purchased
# 0   32      NaN    male        1.0
# 1   23  12323.0  female        1.0
# 2   23   4423.0     NaN        0.0
# 3   44   1345.0  female        NaN
# 4   43  54523.0     NaN        1.0

# %%
df = df.fillna(0)

# %%
df = df.dropna()

# %%
df_sort = df.sort_values(by='gender',ascending=True)

# %%
df_sort.head()
# Out:
#    age   income  gender  purchased
# 1   23  12323.0  female        1.0
# 3   44   1345.0  female        NaN
# 5   12   2312.0  female        1.0
# 0   32      NaN    male        1.0
# 2   23   4423.0     NaN        0.0

# %%
df_grouped = df.groupby('gender').mean()

# %%
df_grouped.head()
# Out:
#               age       income  purchased
# gender
# female  26.333333  5326.666667        1.0
# male    32.000000          NaN        1.0

# %%
df_apply = df['gender'] = df['income'].apply(lambda x: x*2)

# %%
df_apply.head()
# Out:
# 0         NaN
# 1     24646.0
# 2      8846.0
# 3      2690.0
# 4    109046.0
# Name: income, dtype: float64

# %%
df1 = pd.DataFrame({'key':['gender','income'], 'value':['female',12323.0]})
df2 = pd.DataFrame({'key':['gender','income'], 'value':['male','']})

# %%
merged_df = pd.merge(df1,df2, on='key')

# %%
pivot_df = df.pivot_table(values='gender', index='income', aggfunc='mean')
