# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/SHIELA4/BSIS2A_Felicitas-ShielaMaeB/main/example.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        6 non-null      int64
#  1   income     5 non-null      float64
#  2   gender     4 non-null      object
#  3   purchased  5 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 320.0+ bytes
#            gender
# income
# 2312.0     4624.0
# 4423.0     8846.0
# 12323.0   24646.0
# 54523.0  109046.0

# %%
df.head()
# Out:
#    age   income  purchased    gender
# 1   23  12323.0        1.0   24646.0
# 2   23   4423.0        0.0    8846.0
# 4   43  54523.0        1.0  109046.0
# 5   12   2312.0        1.0    4624.0

# %%
df.tail()
# Out:
#    age   income  purchased    gender
# 1   23  12323.0        1.0   24646.0
# 2   23   4423.0        0.0    8846.0
# 4   43  54523.0        1.0  109046.0
# 5   12   2312.0        1.0    4624.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 1 to 5
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4 non-null      int64
#  1   income     4 non-null      float64
#  2   purchased  4 non-null      float64
#  3   gender     4 non-null      float64
# dtypes: float64(3), int64(1)
# memory usage: 160.0 bytes

# %%
df.describe()
# Out:
#              age        income  purchased        gender
# count   4.000000      4.000000       4.00       4.00000
# mean   25.250000  18395.250000       0.75   36790.50000
# std    12.919623  24467.537955       0.50   48935.07591
# min    12.000000   2312.000000       0.00    4624.00000
# 25%    20.250000   3895.250000       0.75    7790.50000
# 50%    23.000000   8373.000000       1.00   16746.00000
# 75%    28.000000  22873.000000       1.00   45746.00000
# max    43.000000  54523.000000       1.00  109046.00000

# %%
df.shape
# Out:
# (4, 4)

# %%
df.columns
# Out:
# Index(['age', 'income', 'purchased', 'gender'], dtype='object')

# %%
df = df.drop('gender', axis=1)

# %%
df.head()
# Out:
#    age   income  purchased
# 1   23  12323.0        1.0
# 2   23   4423.0        0.0
# 4   43  54523.0        1.0
# 5   12   2312.0        1.0

# %%
df_filna = df.fillna(0)

# %%
df_filna.head()
# Out:
#    age   income  purchased
# 1   23  12323.0        1.0
# 2   23   4423.0        0.0
# 4   43  54523.0        1.0
# 5   12   2312.0        1.0

# %%
df = df.dropna()

# %%
df_sort = df.sort_values(by='income', ascending=True)

# %%
df_sort.head()
# Out:
#    age   income  purchased
# 5   12   2312.0        1.0
# 2   23   4423.0        0.0
# 1   23  12323.0        1.0
# 4   43  54523.0        1.0

# %%
df_grouped=df.groupby('income').mean()

# %%
df_grouped.head()
# Out:
#           age  purchased
# income
# 2312.0   12.0        1.0
# 4423.0   23.0        0.0
# 12323.0  23.0        1.0
# 54523.0  43.0        1.0

# %%
df_apply=df['gender'] = df['income'].apply(lambda x: x*2)

# %%
df_apply.head()
# Out:
# 1     24646.0
# 2      8846.0
# 4    109046.0
# 5      4624.0
# Name: income, dtype: float64

# %%
df1 = pd.DataFrame({'key':['age', 'income'], 'values':['female', 12323.0]})
df2 = pd.DataFrame({'key':['age', 'income'], 'values':['male', '']})

# %%
merged_df = pd.merge(df1,df2, on='key')

# %%
merged_df.head()
# Out:
#       key values_x values_y
# 0     age   female     male
# 1  income  12323.0

# %%
pivot_df = df.pivot_table(values= 'gender', index='income', aggfunc= 'mean')

# %%
pivot_df.head()
# Out:
#            gender
# income
# 2312.0     4624.0
# 4423.0     8846.0
# 12323.0   24646.0
# 54523.0  109046.0
