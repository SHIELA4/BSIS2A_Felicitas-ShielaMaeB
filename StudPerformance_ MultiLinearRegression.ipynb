# %%
# Student Performance Multiple Linear Regression

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('https://raw.githubusercontent.com/SHIELA4/BSIS2A_Felicitas-ShielaMaeB/refs/heads/main/Student_Performance.csv')

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
X_multi = df[["Sample Question Papers Practiced", "Previous Scores"]]
y = df["Performance Index"]
model_multi = LinearRegression()
model_multi.fit(X_multi, y)

print("Intercept:", model_multi.intercept_)
print("Coefficients:", model_multi.coef_)
# Out:
# Intercept: -16.26707309061115
# Coefficients: [0.24156198 1.01352167]

# %%
y_pred = model_multi.predict(X_multi)

# %%
print(y_pred)
# Out:
# [84.31313457 67.32482809 35.90565621 ... 69.0630357  82.04452924
#  58.97509273]

# %%
plt.scatter(X_multi['Sample Question Papers Practiced'], y, color = 'black')
plt.plot(X_multi['Sample Question Papers Practiced'], y_pred, color = 'gray')
plt.title("Multiple Linear Regression (Previous Scores, Hours Studied)")
plt.xlabel("Hours Studied")
plt.ylabel("Previous Scores")
plt.show()

# %%
print(y_pred.min())
# Out:
# 24.27379385144237

# %%
print(y_pred.max())
# Out:
# 86.24563037706496
